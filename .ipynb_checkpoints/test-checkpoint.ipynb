# %%
import re 
from lxml import etree
import traceback

# %%
import requests
session = requests.Session()
session.headers.update({
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
})

# %%
def fetch_single_final_link(link):
    """Worker function to fetch one intermediate page and extract the final link."""
    try:
        response = session.get(link, timeout=10)
        response.raise_for_status()
        link_regex = re.compile(r'window\.open\("([^"]+)"\)')
        match = link_regex.search(response.text)
        print(match)
        if match:
            return match.group(1)
    except requests.exceptions.RequestException:
        # Errors are ignored for single link fetches to not stop the whole process
        traceback.print_exc()
    except Exception as e:
        traceback.print_exc()
    return None

# %%
fetch_single_final_link("https://fuckingfast.co/ej6fiyhryqs9#Mafia_3_Definitive_Edition_--_fitgirl-repacks.site_--_.part01.rar")
# Out:
# <re.Match object; span=(3801, 4023), match='window.open("https://dl.fuckingfast.co/dl/T9R-Nr5>
# 'https://dl.fuckingfast.co/dl/T9R-Nr5xpCg4-QmTBnwULe0JH8dTcRLYJQP6td1RhLnvtewvq_5QtfLMxycPnOoHq5vasXsLMusTpqIjiYzQb6qMSE4UeDQbwZ_uLMiP3TYkjNP5Lyl8Ux5S8gxijpQI2KDqAm-KVr4LR8AZSrnujiEAX4trFLtFap54xHTs6k_aJw1V0w'

# %%
response = session.get("https://fuckingfast.co/ej6fiyhryqs9#Mafia_3_Definitive_Edition_--_fitgirl-repacks.site_--_.part01.rar", timeout=10)

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta content="width=device-width, initial-scale=1.0" name="viewport">
#     <title>Mafia_3_Definitive_Edition_--_fitgirl-repacks.site_--_.part01.rar</title>
#     <meta name="title" content="Mafia_3_Definitive_Edition_--_fitgirl-repacks.site_--_.part01.rar">
#     <meta name="description" content="Fucking fast file hosting service">
#     <meta name="application-name" content="fuckingfast.co">
#     <link rel="shortcut icon" href="/static/favicon.ico">
#     <script src="/static/bundle.js?v=174b03882b2de16e6c9cdab7dc84e43c499ae480-dirty" defer></script>
#     <link rel="stylesheet" href="/static/whysostylish.css?v=174b03882b2de16e6c9cdab7dc84e43c499ae480-dirty">
#     <script src="https://challenges.cloudflare.com/turnstile/v0/api.js" defer></script>
#
#
#
# ...
